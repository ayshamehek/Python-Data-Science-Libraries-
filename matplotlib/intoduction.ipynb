# %% [markdown]
# import matplotlib

# %%
import matplotlib.pyplot as plt

days = ["Mon", "Tue", "Wed", "Thu", "Fri","sat"]
items = [33,70, 65, 95, 47, 88]

plt.plot(days, sales)

plt.title("stationery shop")
plt.xlabel("Days")
plt.ylabel("items")

plt.show()

# %% [markdown]
# student marks

# %%
import matplotlib.pyplot as plt
subjects=["science","kannada","english","maths"]
marks=[99,45,88,59]
plt.plot(subjects, marks)
plt.xlabel("subjects")
plt.ylabel("marks")
plt.title("student marks")
plt.show()

# %% [markdown]
# pie chart

# %%
import matplotlib.pyplot as plt

expenses = [3000, 2000, 1000, 4000]

labels = ["Food", "Shopping", "Travel", "Savings"]

plt.pie(expenses, labels=labels)

plt.show()

# %% [markdown]
# Line Plot

# %%
import matplotlib.pyplot as plt

days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
sales = [120, 150, 170, 140, 190]

plt.plot(days, sales)

plt.title("Weekly Sales")
plt.xlabel("Days")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# Line Plot

# %%
import matplotlib.pyplot as plt
days = ["Mon", "Tue", "Wed", "Thu", "Fri"] 
sales = [100, 150, 120, 180, 160] 
plt.plot(days, sales) 
plt.title("Daily Sales") 
plt.xlabel("Days") 
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# Stem Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 25, 15, 30, 20]

plt.stem(x, y)

plt.title("Stem Plot")

plt.show()

# %% [markdown]
# Step Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 3, 5, 6]

plt.step(x, y)

plt.title("Step Plot")

plt.show()

# %% [markdown]
# Error Bar Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [20, 35, 30, 40]
error = [2, 3, 2, 4]

plt.errorbar(x, y, yerr=error)

plt.title("Error Bar Plot")

plt.show()

# %% [markdown]
#  3D Surface Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

x = np.linspace(-5, 5, 30)
y = np.linspace(-5, 5, 30)

X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z)

plt.title("3D Surface Plot")

plt.show()

# %% [markdown]
# Count Plot with Titanic Dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset("titanic")

sns.countplot(x="sex", data=titanic)

plt.title("Male vs Female Passengers")
plt.show()

# %% [markdown]
# Count Plot with Hue

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset("titanic")

sns.countplot(x="sex", hue="survived", data=titanic)

plt.title("Survival by Gender")
plt.show()

# %% [markdown]
# Multiple Line Plot

# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5]

sales1 = [200,250,220,300,350]
sales2 = [180,230,210,290,330]

plt.plot(days, sales1, label="Shop A")
plt.plot(days, sales2, label="Shop B")

plt.legend()

plt.show()
