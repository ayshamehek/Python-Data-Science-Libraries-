# %% [markdown]
# scatterplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.scatterplot(x="total_bill", y="tip", data=tips)

plt.show()

# %% [markdown]
# line plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

flights = sns.load_dataset("flights")

sns.lineplot(x="year", y="passengers", data=flights)

plt.show()

# %% [markdown]
# count plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.countplot(x="day", data=tips)

plt.show()

# %% [markdown]
# swarmplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.boxplot(
    data=tips,
    x="day",
    y="total_bill",
    color="lightgray"
)

sns.swarmplot(
    data=tips,
    x="day",
    y="total_bill",
    color="black",
    size=4
)

plt.title("Box Plot with Swarm Plot")
plt.show()

# %% [markdown]
# overlay on a violin plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.violinplot(
    data=tips,
    x="day",
    y="total_bill",
    inner=None,
    color="lightblue"
)

sns.swarmplot(
    data=tips,
    x="day",
    y="total_bill",
    color="black",
    size=3
)

plt.title("Violin Plot with Swarm Plot")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Class": ["A", "A", "A", "A", "B", "B", "B", "B"],
    "Marks": [75, 82, 90, 85, 65, 70, 88, 92]
}

df = pd.DataFrame(data)

sns.swarmplot(x="Class", y="Marks", data=df)

plt.title("Students' Marks by Class")
plt.xlabel("Class")
plt.ylabel("Marks")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Department": ["HR", "HR", "HR", "IT", "IT", "IT", "Sales", "Sales", "Sales"],
    "Salary": [30000, 35000, 32000, 50000, 55000, 53000, 40000, 42000, 45000]
}

df = pd.DataFrame(data)

sns.swarmplot(x="Department", y="Salary", data=df)

plt.title("Employee Salary by Department")
plt.xlabel("Department")
plt.ylabel("Salary")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.swarmplot(
    x="day",
    y="total_bill",
    hue="sex",
    data=tips
)

plt.title("Total Bill by Day and Gender")
plt.show()

# %% [markdown]
# KDE PLOT

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.kdeplot(x=tips["total_bill"], fill=True)

plt.title("KDE Plot")
plt.show()

# %% [markdown]
# Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

corr = tips.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Student Marks Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

marks = pd.DataFrame({
    "Math": [85, 90, 78, 92],
    "Science": [88, 76, 80, 95],
    "English": [90, 85, 82, 91]
}, index=["Alice", "Bob", "Charlie", "David"])

sns.heatmap(marks, annot=True, cmap="YlGnBu")

plt.title("Student Marks Heatmap")
plt.show()

# %% [markdown]
# Sales Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sales = pd.DataFrame({
    "Jan": [100, 120, 90],
    "Feb": [150, 130, 110],
    "Mar": [170, 140, 125]
}, index=["Laptop", "Mobile", "Tablet"])

sns.heatmap(sales, annot=True, cmap="Oranges")

plt.title("Monthly Sales")
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

corr = tips.corr(numeric_only=True)

sns.heatmap(corr,
            annot=True,
            cmap="coolwarm",
            linewidths=1)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Line Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

flights = sns.load_dataset("flights")

sns.lineplot(x="year", y="passengers", data=flights)

plt.title("Passengers Over Years")
plt.show()

# %% [markdown]
# Bar Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.barplot(x="day", y="total_bill", data=tips)

plt.title("Average Bill by Day")
plt.show()

# %% [markdown]
# Tips Dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.boxplot(x="day", y="total_bill", data=tips)

plt.title("Total Bill by Day")
plt.show()

# %% [markdown]
# Heatmap Without NumbersHeatmap Without Numbers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.DataFrame({
    "A":[10,20,30],
    "B":[15,25,35],
    "C":[5,10,15]
})

sns.heatmap(data,
            cmap="Blues",
            annot=False)

plt.title("Heatmap Without Values")
plt.show()

# %% [markdown]
# Heatmap with Different Colors

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.DataFrame({
    "A":[5,10,15],
    "B":[20,25,30],
    "C":[35,40,45]
})

sns.heatmap(data,
            annot=True,
            cmap="viridis")

plt.title("Viridis Heatmap")
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

corr = tips.corr(numeric_only=True)

sns.heatmap(corr,
            annot=True,
            cmap="coolwarm",
            linewidths=1)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Profit Trend

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

profit = pd.DataFrame({
    "Year":[2021,2022,2023,2024,2025],
    "Profit":[10,15,25,30,40]
})

sns.lineplot(x="Year", y="Profit", data=profit)

plt.title("Company Profit")
plt.show()

# %% [markdown]
# Temperature Change

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

weather = pd.DataFrame({
    "Day":[1,2,3,4,5,6,7],
    "Temperature":[30,31,29,32,34,33,35]
})

sns.lineplot(x="Day", y="Temperature", data=weather)

plt.title("Temperature Change")
plt.show()

# %% [markdown]
# Monthly Sales

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sales = pd.DataFrame({
    "Month": ["Jan","Feb","Mar","Apr","May","Jun"],
    "Sales": [200,250,300,280,350,400]
})

sns.lineplot(x="Month", y="Sales", data=sales)

plt.title("Monthly Sales")
plt.show()
